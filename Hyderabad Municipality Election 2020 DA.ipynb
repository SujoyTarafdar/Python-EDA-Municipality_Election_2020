# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
me_df=pd.read_csv("C:\\Users\\sujoy\\OneDrive\\Desktop\\Python EDA\\GHMC Election 2020\\GHMC Election 2020.csv")

# %%
me_df.head()
# Out:
#   Name of the Municiplaity/corporation        Ward No. Ward reserved for  \
# 0                                 GHMC  Ward 1 - Kapra             SC(G)
# 1                                 GHMC  Ward 1 - Kapra             SC(G)
# 2                                 GHMC  Ward 1 - Kapra             SC(G)
# 3                                 GHMC  Ward 1 - Kapra             SC(G)
# 4                                 GHMC  Ward 1 - Kapra             SC(G)
#
#    Total No. of Voters including service voters in the ward  \
# 0                                              46223
# 1                                              46223
# 2                                              46223
# 3                                              46223
# 4                                              46223
#
#    Total Votes Polled (excluding PBs) in the ward  \
# 0                                           20847
# 1                                           20847
# 2                                           20847
# 3                                           20847
# 4                                           20847
#
#    No. of Postal Ballots Polled in the ward  \
# 0                                        18
# 1                                        18
# 2                                        18
# 3                                        18
# 4                                        18
#
#    No. of Tendered Votes Polled in the ward  \
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         0
#
#    No. of Valid Votes (including PBs) in the ward  \
# 0                                           20245
# 1                                           20245
# 2                                           20245
# 3                                           20245
# 4                                           20245
#
#    No. of Rejected Votes Polled (including PBs) in the ward  \
# 0                                                401
# 1                                                401
# 2                                                401
# 3                                                401
# 4                                                401
#
#    No. of Votes Polled to NOTA (including PBs) in the ward  \
# 0                                                219
# 1                                                219
# 2                                                219
# 3                                                219
# 4                                                219
#
#    Sl.No. of the Candidate in the ward  \
# 0                                    1
# 1                                    2
# 2                                    3
# 3                                    4
# 4                                    5
#
#   Name of the Contesting Candidate in the ward  \
# 0                      ALLAKONDKAR VINOD KUMAR
# 1                                  PATHI KUMAR
# 2                        MUNIGADAPA SREERAMULU
# 3                                 S.SWARNA RAJ
# 4                     KANDREGULA VENUGOPAL RAO
#
#    No. of Valid Votes Secured (including PBs) by the candidate  \
# 0                                               6684
# 1                                               3631
# 2                                                788
# 3                                               8762
# 4                                                380
#
#   Party Affiliation if any   Result
# 0                      BJP      NaN
# 1                      INC      NaN
# 2                      TDP      NaN
# 3                      TRS  Elected
# 4                     TJSP      NaN

# %%
me_df.tail()
# Out:
#      Name of the Municiplaity/corporation                 Ward No.  \
# 1117                                 GHMC      Ward 149 - Begumpet
# 1118                                 GHMC  Ward 150 - Monda Market
# 1119                                 GHMC  Ward 150 - Monda Market
# 1120                                 GHMC  Ward 150 - Monda Market
# 1121                                 GHMC  Ward 150 - Monda Market
#
#      Ward reserved for  \
# 1117             UR(W)
# 1118             UR(W)
# 1119             UR(W)
# 1120             UR(W)
# 1121             UR(W)
#
#       Total No. of Voters including service voters in the ward  \
# 1117                                              50963
# 1118                                              49348
# 1119                                              49348
# 1120                                              49348
# 1121                                              49348
#
#       Total Votes Polled (excluding PBs) in the ward  \
# 1117                                           23797
# 1118                                           22280
# 1119                                           22280
# 1120                                           22280
# 1121                                           22280
#
#       No. of Postal Ballots Polled in the ward  \
# 1117                                        21
# 1118                                        13
# 1119                                        13
# 1120                                        13
# 1121                                        13
#
#       No. of Tendered Votes Polled in the ward  \
# 1117                                         0
# 1118                                         0
# 1119                                         0
# 1120                                         0
# 1121                                         0
#
#       No. of Valid Votes (including PBs) in the ward  \
# 1117                                           23069
# 1118                                           21665
# 1119                                           21665
# 1120                                           21665
# 1121                                           21665
#
#       No. of Rejected Votes Polled (including PBs) in the ward  \
# 1117                                                605
# 1118                                                426
# 1119                                                426
# 1120                                                426
# 1121                                                426
#
#       No. of Votes Polled to NOTA (including PBs) in the ward  \
# 1117                                                144
# 1118                                                202
# 1119                                                202
# 1120                                                202
# 1121                                                202
#
#       Sl.No. of the Candidate in the ward  \
# 1117                                    5
# 1118                                    1
# 1119                                    2
# 1120                                    3
# 1121                                    4
#
#      Name of the Contesting Candidate in the ward  \
# 1117                        CHEKKALA KANCHANAMALA
# 1118                                  Akula Rupha
# 1119                              Kontham Deepika
# 1120                  Bandhanadam Bala Prashanthi
# 1121                                  B. Sai Rani
#
#       No. of Valid Votes Secured (including PBs) by the candidate  \
# 1117                                                 86
# 1118                                               8068
# 1119                                              12015
# 1120                                               1087
# 1121                                                495
#
#      Party Affiliation if any   Result
# 1117              INDEPENDENT      NaN
# 1118                      TRS      NaN
# 1119                      BJP  Elected
# 1120                      INC      NaN
# 1121                      TDP      NaN

# %%
## Checking for Duplicate rows 

me_df[me_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Name of the Municiplaity/corporation, Ward No., Ward reserved for, Total No. of Voters including service voters in the ward, Total Votes Polled (excluding PBs) in the ward, No. of Postal Ballots Polled in the ward, No. of Tendered Votes Polled in the ward, No. of Valid Votes (including PBs) in the ward, No. of Rejected Votes Polled (including PBs) in the ward, No. of Votes Polled to NOTA (including PBs) in the ward, Sl.No. of the Candidate in the ward, Name of the Contesting Candidate in the ward, No. of Valid Votes Secured (including PBs) by the candidate, Party Affiliation if any, Result]
# Index: []

# %%
## Checking for Null Values (NaN present in Result column can be neglected)

me_df.isnull().sum()
# Out:
# Name of the Municiplaity/corporation                             0
# Ward No.                                                         0
# Ward reserved for                                                0
# Total No. of Voters including service voters in the ward         0
# Total Votes Polled (excluding PBs) in the ward                   0
# No. of Postal Ballots Polled in the ward                         0
# No. of Tendered Votes Polled in the ward                         0
# No. of Valid Votes (including PBs) in the ward                   0
# No. of Rejected Votes Polled (including PBs) in the ward         0
# No. of Votes Polled to NOTA (including PBs) in the ward          0
# Sl.No. of the Candidate in the ward                              0
# Name of the Contesting Candidate in the ward                     0
# No. of Valid Votes Secured (including PBs) by the candidate      0
# Party Affiliation if any                                         0
# Result                                                         972
# dtype: int64

# %%
me_df.columns
# Out:
# Index(['Name of the Municiplaity/corporation', 'Ward No.', 'Ward reserved for',
#        'Total No. of Voters including service voters in the ward',
#        'Total Votes Polled (excluding PBs) in the ward',
#        'No. of Postal Ballots Polled in the ward',
#        'No. of Tendered Votes Polled in the ward',
#        'No. of Valid Votes (including PBs) in the ward',
#        'No. of Rejected Votes Polled (including PBs) in the ward',
#        'No. of Votes Polled to NOTA (including PBs) in the ward',
#        'Sl.No. of the Candidate in the ward',
#        'Name of the Contesting Candidate in the ward',
#        'No. of Valid Votes Secured (including PBs) by the candidate',
#        'Party Affiliation if any', 'Result'],
#       dtype='object')

# %%
me_df.info
# Out:
# <bound method DataFrame.info of      Name of the Municiplaity/corporation                 Ward No.  \
# 0                                    GHMC           Ward 1 - Kapra
# 1                                    GHMC           Ward 1 - Kapra
# 2                                    GHMC           Ward 1 - Kapra
# 3                                    GHMC           Ward 1 - Kapra
# 4                                    GHMC           Ward 1 - Kapra
# ...                                   ...                      ...
# 1117                                 GHMC      Ward 149 - Begumpet
# 1118                                 GHMC  Ward 150 - Monda Market
# 1119                                 GHMC  Ward 150 - Monda Market
# 1120                                 GHMC  Ward 150 - Monda Market
# 1121                                 GHMC  Ward 150 - Monda Market
#
#      Ward reserved for  \
# 0                SC(G)
# 1                SC(G)
# 2                SC(G)
# 3                SC(G)
# 4                SC(G)
# ...                ...
# 1117             UR(W)
# 1118             UR(W)
# 1119             UR(W)
# 1120             UR(W)
# 1121             UR(W)
#
#       Total No. of Voters including service voters in the ward  \
# 0                                                 46223
# 1                                                 46223
# 2                                                 46223
# 3                                                 46223
# 4                                                 46223
# ...                                                 ...
# 1117                                              50963
# 1118                                              49348
# 1119                                              49348
# 1120                                              49348
# 1121                                              49348
#
#       Total Votes Polled (excluding PBs) in the ward  \
# 0                                              20847
# 1                                              20847
# 2                                              20847
# 3                                              20847
# 4                                              20847
# ...                                              ...
# 1117                                           23797
# 1118                                           22280
# 1119                                           22280
# 1120                                           22280
# 1121                                           22280
#
#       No. of Postal Ballots Polled in the ward  \
# 0                                           18
# 1                                           18
# 2                                           18
# 3                                           18
# 4                                           18
# ...                                        ...
# 1117                                        21
# 1118                                        13
# 1119                                        13
# 1120                                        13
# 1121                                        13
#
#       No. of Tendered Votes Polled in the ward  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
# ...                                        ...
# 1117                                         0
# 1118                                         0
# 1119                                         0
# 1120                                         0
# 1121                                         0
#
#       No. of Valid Votes (including PBs) in the ward  \
# 0                                              20245
# 1                                              20245
# 2                                              20245
# 3                                              20245
# 4                                              20245
# ...                                              ...
# 1117                                           23069
# 1118                                           21665
# 1119                                           21665
# 1120                                           21665
# 1121                                           21665
#
#       No. of Rejected Votes Polled (including PBs) in the ward  \
# 0                                                   401
# 1                                                   401
# 2                                                   401
# 3                                                   401
# 4                                                   401
# ...                                                 ...
# 1117                                                605
# 1118                                                426
# 1119                                                426
# 1120                                                426
# 1121                                                426
#
#       No. of Votes Polled to NOTA (including PBs) in the ward  \
# 0                                                   219
# 1                                                   219
# 2                                                   219
# 3                                                   219
# 4                                                   219
# ...                                                 ...
# 1117                                                144
# 1118                                                202
# 1119                                                202
# 1120                                                202
# 1121                                                202
#
#       Sl.No. of the Candidate in the ward  \
# 0                                       1
# 1                                       2
# 2                                       3
# 3                                       4
# 4                                       5
# ...                                   ...
# 1117                                    5
# 1118                                    1
# 1119                                    2
# 1120                                    3
# 1121                                    4
#
#      Name of the Contesting Candidate in the ward  \
# 0                         ALLAKONDKAR VINOD KUMAR
# 1                                     PATHI KUMAR
# 2                           MUNIGADAPA SREERAMULU
# 3                                    S.SWARNA RAJ
# 4                        KANDREGULA VENUGOPAL RAO
# ...                                           ...
# 1117                        CHEKKALA KANCHANAMALA
# 1118                                  Akula Rupha
# 1119                              Kontham Deepika
# 1120                  Bandhanadam Bala Prashanthi
# 1121                                  B. Sai Rani
#
#       No. of Valid Votes Secured (including PBs) by the candidate  \
# 0                                                  6684
# 1                                                  3631
# 2                                                   788
# 3                                                  8762
# 4                                                   380
# ...                                                 ...
# 1117                                                 86
# 1118                                               8068
# 1119                                              12015
# 1120                                               1087
# 1121                                                495
#
#      Party Affiliation if any   Result
# 0                         BJP      NaN
# 1                         INC      NaN
# 2                         TDP      NaN
# 3                         TRS  Elected
# 4                        TJSP      NaN
# ...                       ...      ...
# 1117              INDEPENDENT      NaN
# 1118                      TRS      NaN
# 1119                      BJP  Elected
# 1120                      INC      NaN
# 1121                      TDP      NaN
#
# [1122 rows x 15 columns]>

# %%
## Counting the Number of Wards in Hyderabad Muncipality

Count_of_Wards=me_df['Ward No.'].value_counts()

# %%
Count_of_Wards
# Out:
# Ward 45 - Jangammet           20
# Ward 102 - Rahmath nagar      14
# Ward 77 - Jambagh             14
# Ward 51 - Gosha mahal         14
# Ward 93 - Banjara hills       14
#                               ..
# Ward 42 - Barkas               3
# Ward 47 - Nawabsaheb kunta     3
# Ward 10 - Uppal                3
# Ward 68 - Tolichowki           3
# Ward 132 - Jeedimetla          3
# Name: Ward No., Length: 150, dtype: int64

# %%
## Counting the Number of Wards Reserved Caste wise in Hyderabad Muncipality

Wards_reserved=me_df['Ward reserved for'].value_counts()

# %%
Wards_reserved
# Out:
# UR(G)    408
# UR(W)    291
# BC(G)    179
# BC(W)    163
# SC(G)     36
# SC(W)     33
# ST(W)      6
# ST(G)      6
# Name: Ward reserved for, dtype: int64

# %%
## Plotting Line Plot for Wards Reserved Caste wise

sns.lineplot(data=Wards_reserved)
# Out:
# <AxesSubplot:ylabel='Ward reserved for'>

# %%
## Total Voters in Each Ward

Total_Voters_in_Each_Ward=me_df.groupby('Ward No.').sum('Total No. of Voters including service voters in the ward')

# %%
Total_Voters_in_Each_Ward[:2]
# Out:
#                  Total No. of Voters including service voters in the ward  \
# Ward No.
# Ward 1 - Kapra                                              231115
# Ward 10 - Uppal                                             165135
#
#                  Total Votes Polled (excluding PBs) in the ward  \
# Ward No.
# Ward 1 - Kapra                                           104235
# Ward 10 - Uppal                                           84534
#
#                  No. of Postal Ballots Polled in the ward  \
# Ward No.
# Ward 1 - Kapra                                         90
# Ward 10 - Uppal                                        48
#
#                  No. of Tendered Votes Polled in the ward  \
# Ward No.
# Ward 1 - Kapra                                          0
# Ward 10 - Uppal                                         0
#
#                  No. of Valid Votes (including PBs) in the ward  \
# Ward No.
# Ward 1 - Kapra                                           101225
# Ward 10 - Uppal                                           82233
#
#                  No. of Rejected Votes Polled (including PBs) in the ward  \
# Ward No.
# Ward 1 - Kapra                                                2005
# Ward 10 - Uppal                                               1614
#
#                  No. of Votes Polled to NOTA (including PBs) in the ward  \
# Ward No.
# Ward 1 - Kapra                                                1095
# Ward 10 - Uppal                                                735
#
#                  Sl.No. of the Candidate in the ward  \
# Ward No.
# Ward 1 - Kapra                                    15
# Ward 10 - Uppal                                    6
#
#                  No. of Valid Votes Secured (including PBs) by the candidate
# Ward No.
# Ward 1 - Kapra                                               20245
# Ward 10 - Uppal                                              27411

# %%
## Total Voters Voted on Election Day

me_df.groupby('Ward No.')[['Total Votes Polled (excluding PBs) in the ward','No. of Postal Ballots Polled in the ward']].sum()
# Out:
#                            Total Votes Polled (excluding PBs) in the ward  \
# Ward No.
# Ward 1 - Kapra                                                     104235
# Ward 10 - Uppal                                                     84534
# Ward 100 - Sanathnagar                                             121290
# Ward 101 - Erragadda                                               170205
# Ward 102 - Rahmath nagar                                           408058
# ...                                                                   ...
# Ward 95 - Jubilee hills                                            161812
# Ward 96 - Yousufguda                                               198590
# Ward 97 - Somajiguda                                               154812
# Ward 98 - Ameerpet                                                  91920
# Ward 99 - Vengalrao nagar                                          158496
#
#                            No. of Postal Ballots Polled in the ward
# Ward No.
# Ward 1 - Kapra                                                   90
# Ward 10 - Uppal                                                  48
# Ward 100 - Sanathnagar                                           20
# Ward 101 - Erragadda                                             42
# Ward 102 - Rahmath nagar                                         98
# ...                                                             ...
# Ward 95 - Jubilee hills                                          21
# Ward 96 - Yousufguda                                            160
# Ward 97 - Somajiguda                                             35
# Ward 98 - Ameerpet                                               25
# Ward 99 - Vengalrao nagar                                        56
#
# [150 rows x 2 columns]

# %%
me_df['Total Votes Polled (including PBs)'] = me_df['Total Votes Polled (excluding PBs) in the ward'] + me_df['No. of Postal Ballots Polled in the ward']

# %%
me_df
# Out:
#      Name of the Municiplaity/corporation                 Ward No.  \
# 0                                    GHMC           Ward 1 - Kapra
# 1                                    GHMC           Ward 1 - Kapra
# 2                                    GHMC           Ward 1 - Kapra
# 3                                    GHMC           Ward 1 - Kapra
# 4                                    GHMC           Ward 1 - Kapra
# ...                                   ...                      ...
# 1117                                 GHMC      Ward 149 - Begumpet
# 1118                                 GHMC  Ward 150 - Monda Market
# 1119                                 GHMC  Ward 150 - Monda Market
# 1120                                 GHMC  Ward 150 - Monda Market
# 1121                                 GHMC  Ward 150 - Monda Market
#
#      Ward reserved for  \
# 0                SC(G)
# 1                SC(G)
# 2                SC(G)
# 3                SC(G)
# 4                SC(G)
# ...                ...
# 1117             UR(W)
# 1118             UR(W)
# 1119             UR(W)
# 1120             UR(W)
# 1121             UR(W)
#
#       Total No. of Voters including service voters in the ward  \
# 0                                                 46223
# 1                                                 46223
# 2                                                 46223
# 3                                                 46223
# 4                                                 46223
# ...                                                 ...
# 1117                                              50963
# 1118                                              49348
# 1119                                              49348
# 1120                                              49348
# 1121                                              49348
#
#       Total Votes Polled (excluding PBs) in the ward  \
# 0                                              20847
# 1                                              20847
# 2                                              20847
# 3                                              20847
# 4                                              20847
# ...                                              ...
# 1117                                           23797
# 1118                                           22280
# 1119                                           22280
# 1120                                           22280
# 1121                                           22280
#
#       No. of Postal Ballots Polled in the ward  \
# 0                                           18
# 1                                           18
# 2                                           18
# 3                                           18
# 4                                           18
# ...                                        ...
# 1117                                        21
# 1118                                        13
# 1119                                        13
# 1120                                        13
# 1121                                        13
#
#       No. of Tendered Votes Polled in the ward  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
# ...                                        ...
# 1117                                         0
# 1118                                         0
# 1119                                         0
# 1120                                         0
# 1121                                         0
#
#       No. of Valid Votes (including PBs) in the ward  \
# 0                                              20245
# 1                                              20245
# 2                                              20245
# 3                                              20245
# 4                                              20245
# ...                                              ...
# 1117                                           23069
# 1118                                           21665
# 1119                                           21665
# 1120                                           21665
# 1121                                           21665
#
#       No. of Rejected Votes Polled (including PBs) in the ward  \
# 0                                                   401
# 1                                                   401
# 2                                                   401
# 3                                                   401
# 4                                                   401
# ...                                                 ...
# 1117                                                605
# 1118                                                426
# 1119                                                426
# 1120                                                426
# 1121                                                426
#
#       No. of Votes Polled to NOTA (including PBs) in the ward  \
# 0                                                   219
# 1                                                   219
# 2                                                   219
# 3                                                   219
# 4                                                   219
# ...                                                 ...
# 1117                                                144
# 1118                                                202
# 1119                                                202
# 1120                                                202
# 1121                                                202
#
#       Sl.No. of the Candidate in the ward  \
# 0                                       1
# 1                                       2
# 2                                       3
# 3                                       4
# 4                                       5
# ...                                   ...
# 1117                                    5
# 1118                                    1
# 1119                                    2
# 1120                                    3
# 1121                                    4
#
#      Name of the Contesting Candidate in the ward  \
# 0                         ALLAKONDKAR VINOD KUMAR
# 1                                     PATHI KUMAR
# 2                           MUNIGADAPA SREERAMULU
# 3                                    S.SWARNA RAJ
# 4                        KANDREGULA VENUGOPAL RAO
# ...                                           ...
# 1117                        CHEKKALA KANCHANAMALA
# 1118                                  Akula Rupha
# 1119                              Kontham Deepika
# 1120                  Bandhanadam Bala Prashanthi
# 1121                                  B. Sai Rani
#
#       No. of Valid Votes Secured (including PBs) by the candidate  \
# 0                                                  6684
# 1                                                  3631
# 2                                                   788
# 3                                                  8762
# 4                                                   380
# ...                                                 ...
# 1117                                                 86
# 1118                                               8068
# 1119                                              12015
# 1120                                               1087
# 1121                                                495
#
#      Party Affiliation if any   Result  Total Votes Polled (including PBs)
# 0                         BJP      NaN                               20865
# 1                         INC      NaN                               20865
# 2                         TDP      NaN                               20865
# 3                         TRS  Elected                               20865
# 4                        TJSP      NaN                               20865
# ...                       ...      ...                                 ...
# 1117              INDEPENDENT      NaN                               23818
# 1118                      TRS      NaN                               22293
# 1119                      BJP  Elected                               22293
# 1120                      INC      NaN                               22293
# 1121                      TDP      NaN                               22293
#
# [1122 rows x 16 columns]

# %%
## Total Votes Per Ward 

Total_Votes_Per_Ward= me_df.groupby('Ward No.')['Total Votes Polled (including PBs)'].sum().reset_index().sort_values(by='Total Votes Polled (including PBs)',ascending=False)

# %%
Total_Votes_Per_Ward
# Out:
#                        Ward No.  Total Votes Polled (including PBs)
# 90          Ward 45 - Jangammet                              497020
# 4      Ward 102 - Rahmath nagar                              408156
# 105     Ward 59 - Mylardevpally                              373970
# 29     Ward 125 - Gajularamaram                              356136
# 49           Ward 143 - Tarnaka                              353688
# ..                          ...                                 ...
# 77         Ward 33 - Moghalpura                               77996
# 50         Ward 144 - Mettuguda                               69688
# 115        Ward 68 - Tolichowki                               61746
# 92   Ward 47 - Nawabsaheb kunta                               61719
# 87             Ward 42 - Barkas                               51393
#
# [150 rows x 2 columns]

# %%
## Plotting Total Votes Per Ward

sns.barplot(x='Total Votes Polled (including PBs)',y='Ward No.',data=Total_Votes_Per_Ward)
plt.title('Total Votes Per Ward')
# Out:
# Text(0.5, 1.0, 'Total Votes Per Ward')

# %%
## Voter Turn Out Percentage

me_df['Voter_Turnout_Percentage']=(me_df['Total Votes Polled (including PBs)']/me_df['Total No. of Voters including service voters in the ward'])*100

# %%
me_df['Voter_Turnout_Percentage']
# Out:
# 0       45.139865
# 1       45.139865
# 2       45.139865
# 3       45.139865
# 4       45.139865
#           ...
# 1117    46.735867
# 1118    45.175083
# 1119    45.175083
# 1120    45.175083
# 1121    45.175083
# Name: Voter_Turnout_Percentage, Length: 1122, dtype: float64

# %%
## Plotting Voter Turnout Percentage Per Ward

sns.barplot(x='Voter_Turnout_Percentage',y='Ward No.',data=me_df)
plt.title('Voter Turnout Percentage Per Ward')
# Out:
# Text(0.5, 1.0, 'Voter Turnout Percentage Per Ward')

# %%
# Ward_with_Higher_Voter_Turnout_Percentage

Ward_with_Higher_Voter_Turnout=me_df.nlargest(5,'Voter_Turnout_Percentage')[['Ward No.','Voter_Turnout_Percentage']]

# %%
Ward_with_Higher_Voter_Turnout
# Out:
#                         Ward No.  Voter_Turnout_Percentage
# 834  Ward 112 - Ramachandrapuram                 67.533253
# 835  Ward 112 - Ramachandrapuram                 67.533253
# 836  Ward 112 - Ramachandrapuram                 67.533253
# 837  Ward 112 - Ramachandrapuram                 67.533253
# 838  Ward 112 - Ramachandrapuram                 67.533253

# %%
sns.barplot(x='Ward No.',y='Voter_Turnout_Percentage',data=Ward_with_Higher_Voter_Turnout)
plt.title('Ward_with_Higher_Voter_Turnout %')
# Out:
# Text(0.5, 1.0, 'Ward_with_Higher_Voter_Turnout %')

# %%
# Ward_with_Lower_Voter_Turnout_Percentage

Ward_with_Lower_Voter_Turnout=me_df.nsmallest(5,'Voter_Turnout_Percentage')[['Ward No.','Voter_Turnout_Percentage']]

# %%
Ward_with_Lower_Voter_Turnout
# Out:
#                  Ward No.  Voter_Turnout_Percentage
# 714  Ward 96 - Yousufguda                 33.057783
# 715  Ward 96 - Yousufguda                 33.057783
# 716  Ward 96 - Yousufguda                 33.057783
# 717  Ward 96 - Yousufguda                 33.057783
# 718  Ward 96 - Yousufguda                 33.057783

# %%
sns.barplot(x='Ward No.',y='Voter_Turnout_Percentage',data=Ward_with_Lower_Voter_Turnout)
plt.title('Ward with Lowest Voter Turnout %')
# Out:
# Text(0.5, 1.0, 'Ward with Lowest Voter Turnout %')

# %%
## Party wise Vote Share 

Party_wise_Votes=me_df.groupby('Party Affiliation if any')['Total Votes Polled (including PBs)'].sum().reset_index().sort_values(by='Total Votes Polled (including PBs)',ascending=False)

# %%
Party_wise_Votes
# Out:
#    Party Affiliation if any  Total Votes Polled (including PBs)
# 10              INDEPENDENT                             9811280
# 19                      TRS                             3490411
# 3                       BJP                             3448697
# 9                       INC                             3382981
# 17                      TDP                             2457990
# 1                     AIMIM                             1129939
# 18                     TJSP                              557681
# 5                       CPI                              406247
# 6                       CPM                              289743
# 15                    MCPIU                              265747
# 2            AIMIM INQUILAB                              243204
# 0                      AIFB                              162563
# 4                       BMP                              131027
# 20                      WPI                              101414
# 12                     IPBP                              100359
# 11                    INYJP                               93879
# 8                    HINDJP                               76158
# 7                       DBP                               39689
# 14                      LSP                               24649
# 13                      IPC                               23419
# 16                      MJP                               19875

# %%
sns.barplot(x='Total Votes Polled (including PBs)',y='Party Affiliation if any',data=Party_wise_Votes)
plt.title('Party Wise Votes Gained')
# Out:
# Text(0.5, 1.0, 'Party Wise Votes Gained')
